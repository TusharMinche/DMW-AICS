# %%
# Import necessary libraries
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
# Load the dataset
df = pd.read_csv("C:/Users/digra/Downloads/Tusahr/Titanic.csv")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# 1. Handling Missing Values
# Fill missing values in Age column with mean value
# Using dictionary-like syntax to set values inplace
df['age'] = df['age'].fillna(df['age'].mean())

# Alternatively, using the fillna method directly on the DataFrame without chaining
df.fillna({'age': df['age'].mean()}, inplace=True)

# %%
# Drop rows with missing values in Embarked column
df.dropna(subset=['embarked'], inplace=True)
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# 2. Categorical Encoding
# Convert Sex and Embarked columns to numerical values
le = LabelEncoder()
df['sex'] = le.fit_transform(df['sex'])
df['embarked'] = le.fit_transform(df['embarked'])
df.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare  embarked  class    who  \
# 0         0       3    1  22.0      1      0   7.2500         2  Third    man
# 1         1       1    0  38.0      1      0  71.2833         0  First  woman
# 2         1       3    0  26.0      0      0   7.9250         2  Third  woman
# 3         1       1    0  35.0      1      0  53.1000         2  First  woman
# 4         0       3    1  35.0      0      0   8.0500         2  Third    man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 1       False    C    Cherbourg   yes  False
# 2       False  NaN  Southampton   yes   True
# 3       False    C  Southampton   yes  False
# 4        True  NaN  Southampton    no   True

# %%
# 3. Feature Scaling
# Normalize Fare column
df['fare'] = (df['fare'] - df['fare'].min()) / (df['fare'].max() - df['fare'].min())
df.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch      fare  embarked  class  \
# 0         0       3    1  22.0      1      0  0.014151         2  Third
# 1         1       1    0  38.0      1      0  0.139136         0  First
# 2         1       3    0  26.0      0      0  0.015469         2  Third
# 3         1       1    0  35.0      1      0  0.103644         2  First
# 4         0       3    1  35.0      0      0  0.015713         2  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# 4. Feature Generation
# Create a new feature FamilySize by combining SibSp and Parch
df['FamilySize'] = df['sibsp'] + df['parch'] + 1
df.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch      fare  embarked  class  \
# 0         0       3    1  22.0      1      0  0.014151         2  Third
# 1         1       1    0  38.0      1      0  0.139136         0  First
# 2         1       3    0  26.0      0      0  0.015469         2  Third
# 3         1       1    0  35.0      1      0  0.103644         2  First
# 4         0       3    1  35.0      0      0  0.015713         2  Third
#
#      who  adult_male deck  embark_town alive  alone  FamilySize
# 0    man        True  NaN  Southampton    no  False           2
# 1  woman       False    C    Cherbourg   yes  False           2
# 2  woman       False  NaN  Southampton   yes   True           1
# 3  woman       False    C  Southampton   yes  False           2
# 4    man        True  NaN  Southampton    no   True           1

# %%
# 5. Feature Selection
# Drop unnecessary columns
df.drop(['Name', 'Ticket', 'Cabin'], axis=1, inplace=True)
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch      Fare  Embarked  \
# 0            1         0       3    1  22.0      1      0  0.014151         2
# 1            2         1       1    0  38.0      1      0  0.139136         0
# 2            3         1       3    0  26.0      0      0  0.015469         2
#
#    FamilySize
# 0           2
# 1           2
# 2           1
